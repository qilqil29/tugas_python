# %% [markdown]
# <a href="https://colab.research.google.com/github/qilqil29/tugas_python/blob/main/tugaspython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#operator_aritmatika

#pertambahan
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a + b
print(c)

#pengurangan
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a - b
print(c)

#perkalian
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a * b
print(c)

#pembagian
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a / b
print(c)

#modulus
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a % b
print(c)

#perpangkatan
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a ** b
print(c)

#pembagian bulat
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a // b
print(c)
# Out:
# masukkan angka : 2
# masukan angka:20
# 22
# masukkan angka : 2
# masukan angka:20
# -18
# masukkan angka : 2
# masukan angka:20
# 40
# masukkan angka : 2
# masukan angka:20
# 0.1
# masukkan angka : 2
# masukan angka:20
# 2
# masukkan angka : 2
# masukan angka:20
# 1048576
# masukkan angka : 2
# masukan angka:20
# 0

# %%
#operator_perbandingan

#samadengan
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a == b
print(c)

#tidaksamadengan
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a != b
print(c)

#lebihbesardari
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a > b
print(c)

#lebihkecildari
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a < b
print(c)

#lebihbesaratausamadengan
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a >= b
print(c)

#lebihkecilatausamadengan
a = int(input("masukkan angka : "))
b = int(input("masukan angka:") )
c = a <= b
print(c)
# Out:
# masukkan angka : 3
# masukan angka:4
# False
# masukkan angka : 4
# masukan angka:3
# True
# masukkan angka : 2
# masukan angka:2
# False
# masukkan angka : 3
# masukan angka:2
# False
# masukkan angka : 4
# masukan angka:5
# False
# masukkan angka : 2
# masukan angka:3
# True

# %%
#operator_logika

#truejikakeduapernyataanbenar
bilangan_positif = int(input("masukan angka dari 1-10 : "))
is_positif = bilangan_positif > 0 and bilangan_positif < 10
print(is_positif)
# Out:
# masukan angka dari 1-10 : 4
# True

# %%
#kakulatorsederhana_python

angka1 = int(input("masukkan angka pertama : "))
angka2 = int(input("masukkan angka kedua : "))

print(angka1 + angka2)
print(angka1 - angka2)
print(angka1 * angka2)
print(angka1 / angka2)
# Out:
# masukkan angka pertama : 4
# masukkan angka kedua : 5
# 9
# -1
# 20
# 0.8

# %% [markdown]
# ![WhatsApp Image 2024-10-13 at 18.14.47_9bef5478.jpg](data:image/jpeg;base64,...)![WhatsApp Image 2024-10-13 at 18.14.45_8542ed9a.jpg](data:image/jpeg;base64,...)![tugas python.jpg](data:image/jpeg;base64,...)
